# %%
import random

import matplotlib.pyplot as py
import scipy
import sklearn
import numpy
from pyAudioAnalysis import audioBasicIO as ai
from pyAudioAnalysis import audioFeatureExtraction as ac

# %%
[fs, x] = ai.readAudioFile('test.wav')
sf, y = ai.readAudioFile('sound.wav')

# F = ac.stFeatureExtraction(x[:,0], fs, 0.050 * fs, 0.025 * fs)
# py.subplot(1,2,1)
# py.plot(F[0, :])
# py.xlabel('Frame No')
# py.ylabel('ZCR')

#py.subplot(2,1,2)
py.plot(y)
py.xlabel('Frame No')
py.ylabel('ZCR')

py.show()
